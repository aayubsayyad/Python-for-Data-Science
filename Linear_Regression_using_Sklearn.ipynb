# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.datasets import make_regression

# %%
# Generating data using make_regression

data = make_regression(n_samples=1000, n_features=1, noise=25)

# %%
X = data[0]
y = data[1]

# %%
data
# Out:
# (array([[-1.90119663e+00],
#         [ 4.73614765e-01],
#         [-1.23498312e+00],
#         [ 1.15829939e+00],
#         [ 8.47320452e-01],
#         [ 1.33049103e+00],
#         [-4.97298313e-01],
#         [ 2.61469003e-01],
#         [-2.57203212e+00],
#         [ 5.29354883e-01],
#         [ 2.10767948e+00],
#         [-1.76859017e+00],
#         [-5.58057633e-01],
#         [ 2.59155731e+00],
#         [ 2.14252767e-01],
#         [ 7.19193348e-01],
#         [ 1.76609892e+00],
#         [-1.76886012e+00],
#         [ 6.68180182e-01],
#         [-9.94841497e-01],
#         [ 7.68272296e-01],
#         [ 7.99362232e-01],
#         [ 1.02996609e-01],
#         [ 9.34596860e-01],
#         [ 5.12532102e-01],
#         [-9.18273565e-01],
#         [-2.50112073e-02],
#         [-1.02486516e+00],
#         [ 8.13732008e-01],
#         [ 1.00593283e+00],
#         [-5.04211420e-01],
#         [ 1.36655722e-01],
#         [ 9.42027673e-02],
#         [-1.51028012e+00],
# ...

# %%
type(data)
# Out:
# tuple

# %%
df = pd.DataFrame(X, columns=["Feature1"])
df["Target"] = y

# %%
df.head()
# Out:
#    Feature1     Target
# 0 -1.901197 -61.159861
# 1  0.473615  11.458894
# 2 -1.234983 -41.246667
# 3  1.158299  37.692444
# 4  0.847320  -5.273059

# %%
plt.title("Feature vs Target")
plt.scatter(df["Feature1"], df["Target"])
plt.show()

# %% [markdown]
# ## train test split
#
# # Train test split
#
# # Return ----------->
# # X_train -> All the input features for training
# # X_test -> All the input features for testing
# # y_train -> Target column for training
# # y_test -> Target for testing
#
# # Input ----------->
# # X -> All the input features from numpy array or pandas dataframe
# # y -> Target variable as numpy array or pandas dataframe column
# # train_size or test_size (0.0 to 1.0)-> To determine how many rows will be in train data
# # and how many rows will be in test data
# # random_state -> To ensure the data not to change at every refresh

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=57)

# %%
X_train.shape
# Out:
# (750, 1)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
y_train.shape
# Out:
# (750,)

# %%
y_test.shape
# Out:
# (250,)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# ##### On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6989719053637058

# %%
model.coef_
# Out:
# array([37.83061411])

# %%
model.intercept_
# Out:
# -2.234048145563924

# %%
y_mean = y_test.mean()

# %%
y_mean
# Out:
# -5.89899858230978

# %%
TSS = np.sum(np.square(y_test - y_mean))
TSS
# Out:
# 520333.25755892054

# %%
SSR = np.sum(np.square(y_test - y_pred))
SSR
# Out:
# 156634.92909885795

# %%
r2 =1 - (SSR/TSS)
r2
# Out:
# 0.6989719053637058
